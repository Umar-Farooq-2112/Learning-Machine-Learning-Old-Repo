# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Position_Salaries.csv")
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
l_regressor = LinearRegression()
l_regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
p_regressor = PolynomialFeatures(degree = 2)
x_pol = p_regressor.fit_transform(x)
l_reg_2 = LinearRegression()
l_reg_2.fit(x_pol,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,l_regressor.predict(x),color='blue')
plt.title('Truth or Bluff(Linear Regression)')
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,l_reg_2.predict(p_regressor.fit_transform(x)),color='blue')
plt.title('Truth or Bluff(Li near Regression)')
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()

# %%
l_regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
l_reg_2.predict(p_regressor.fit_transform([[6.5]]))
# Out:
# array([189498.10606061])
